# %% [markdown]
# # Introduction
# Data wrangling(数据整理)

# %% [markdown]
# Load data from mysql (user:root password:zzm123 ip:10.5.11.96:3306)

# %%
import pandas as pd
from sqlalchemy import create_engine

#create a connection to the database
database_connection = create_engine("mysql+pymysql://root:zzm123@10.5.11.96:3306/detectordata",echo=True,)

#laod data
dataframe = pd.read_sql_query('SELECT * FROM analog',database_connection)

#view first two rows
dataframe.head(7)
dataframe
#help(create_engine)
# Out:
# 2019-10-31 16:17:17,859 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2019-10-31 16:17:17,861 INFO sqlalchemy.engine.base.Engine {}
# 2019-10-31 16:17:17,879 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2019-10-31 16:17:17,880 INFO sqlalchemy.engine.base.Engine {}
# 2019-10-31 16:17:17,893 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2019-10-31 16:17:17,894 INFO sqlalchemy.engine.base.Engine {}
# 2019-10-31 16:17:17,904 INFO sqlalchemy.engine.base.Engine show collation where `Charset` = 'utf8mb4' and `Collation` = 'utf8mb4_bin'
# 2019-10-31 16:17:17,904 INFO sqlalchemy.engine.base.Engine {}
# 2019-10-31 16:17:17,916 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2019-10-31 16:17:17,917 INFO sqlalchemy.engine.base.Engine {}
# 2019-10-31 16:17:17,922 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# 2019-10-31 16:17:17,923 INFO sqlalchemy.engine.base.Engine {}
# 2019-10-31 16:17:17,928 INFO sqlalchemy.engine.base.Engine SELECT CAST('test collated returns' AS CHAR CHARACTER SET utf8mb4) COLLATE utf8mb4_bin AS anon_1
# 2019-10-31 16:17:17,929 INFO sqlalchemy.engine.base.Engine {}
# 2019-10-31 16:17:17,944 INFO sqlalchemy.engine.base.Engine SELECT * FROM analog
# 2019-10-31 16:17:17,945 INFO sqlalchemy.engine.base.Engine {}
# C:\Users\zhengyi\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 1")
#   result = self._query(query)
#       id    a     m     n     b        u     i       ps  job_id
# 0      6  5.0   6.0   7.0   8.0 -4349.67 -3.85   142.96       1
# 1      7  6.0   7.0   8.0   9.0 -4354.65 -3.83   144.39       1
# 2      8  7.0   8.0   9.0  10.0 -4347.38 -3.87   142.35       1
# 3      9  8.0   9.0  10.0  11.0 -4367.20 -3.76   147.54       1
# 4     10  9.0  10.0  11.0  12.0 -4339.90 -3.93   139.84       1
# ..   ...  ...   ...   ...   ...      ...   ...      ...     ...
# 425  431  3.0  18.0  33.0  48.0 -3912.76 -2.81  2648.04       1
# 426  432  4.0  19.0  34.0  49.0 -4422.55 -3.38  2495.00       1
# 427  433  5.0  20.0  35.0  50.0 -4419.92 -3.40  2471.72       1
# 428  434  6.0  21.0  36.0  51.0 -4416.60 -3.41  2471.40       1
# 429  435  7.0  22.0  37.0  52.0 -4438.34 -3.27  2579.51       1
#
# [430 rows x 9 columns]

# %% [markdown]
# # Creating a Data Frame

# %%
import pandas as pd

dataframe_test = pd.DataFrame()

dataframe_test["Name"]=["Jack","Steven"]
dataframe_test["Age"]=[18,19]
dataframe_test["Drvier"]=[True,False]

dataframe_test
# Out:
#      Name  Age  Drvier
# 0    Jack   18    True
# 1  Steven   19   False

# %% [markdown]
# Append new rows to the botton

# %%
new_person = pd.Series(["MOlly",30,True],index=["Name","Age","Drvier"])
dataframe_test.append(new_person,ignore_index=True)
# Out:
#      Name  Age  Drvier
# 0    Jack   18    True
# 1  Steven   19   False
# 2   MOlly   30    True

# %% [markdown]
# # Describing the Data

# %%
#load library
import pandas as pd

#create url
url = 'C:/Users/zhengyi/Desktop/Python Machine Learning Cookbook/testData/titanic.csv'

#load data as a datafram
datafram = pd.read_csv(url)

#show first 5 rows
print(datafram.head(5))
print(datafram.shape)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# (891, 12)

# %%
#show statistics
datafram.describe()
#not all the describe make sense
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Navigating DataFrames

# %% [markdown]
# select individual data or slices of a DataFrame

# %%
import pandas as pd
url='C:/Users/zhengyi/Desktop/Python Machine Learning Cookbook/testData/titanic.csv'
datafram = pd.read_csv(url)

#select first row
datafram.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                                 22
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
#select 2,3,4 rows
datafram.iloc[1:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
#get all rows up to and including the fourth
datafram.iloc[:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %% [markdown]
# we can set the index of a Dataframe to any value where the value is unique to each row.
# For example, we can set the index to be passenger names and then select rows using a name

# %%
#set index
datafram = datafram.set_index(datafram['Name'])

#show row with a name 
datafram.loc['Heikkinen, Miss. Laina']
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                                26
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: Heikkinen, Miss. Laina, dtype: object

# %% [markdown]
# # Selecting Rows Based on Conditionals

# %% [markdown]
# For example, you want to select all the women on the Titanic

# %%
#show rows where column 'sex' is 'female'
datafram[datafram['Sex']=='female'].head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             9         1
# Nasser, Mrs. Nicholas (Adele Achem)                          10         1
#
#                                                     Pclass  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
# Heikkinen, Miss. Laina                                   3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)        3
# Nasser, Mrs. Nicholas (Adele Achem)                      2
#
#                                                                                                  Name  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  Cumings, Mrs. John Bradley (Florence Briggs Th...
# Heikkinen, Miss. Laina                                                         Heikkinen, Miss. Laina
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# Nasser, Mrs. Nicholas (Adele Achem)                               Nasser, Mrs. Nicholas (Adele Achem)
#
#                                                        Sex   Age  SibSp  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  female  38.0      1
# Heikkinen, Miss. Laina                              female  26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        female  35.0      1
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   female  27.0      0
# Nasser, Mrs. Nicholas (Adele Achem)                 female  14.0      1
#
#                                                     Parch            Ticket  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      0          PC 17599
# Heikkinen, Miss. Laina                                  0  STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            0            113803
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       2            347742
# Nasser, Mrs. Nicholas (Adele Achem)                     0            237736
#
#                                                        Fare Cabin Embarked
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85        C
# Heikkinen, Miss. Laina                               7.9250   NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123        S
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   11.1333   NaN        S
# Nasser, Mrs. Nicholas (Adele Achem)                 30.0708   NaN        C

# %% [markdown]
# Multiple conditions are easy as well. Select the rows where passenger is a male 65 or older.

# %%
#male and 65 or older
datafram[(datafram['Sex']=='male')&(datafram['Age']>=65)].head()
# Out:
#                                 PassengerId  Survived  Pclass  \
# Name
# Wheadon, Mr. Edward H                    34         0       2
# Ostby, Mr. Engelhart Cornelius           55         0       1
# Goldschmidt, Mr. George B                97         0       1
# Connors, Mr. Patrick                    117         0       3
# Duane, Mr. Frank                        281         0       3
#
#                                                           Name   Sex   Age  \
# Name
# Wheadon, Mr. Edward H                    Wheadon, Mr. Edward H  male  66.0
# Ostby, Mr. Engelhart Cornelius  Ostby, Mr. Engelhart Cornelius  male  65.0
# Goldschmidt, Mr. George B            Goldschmidt, Mr. George B  male  71.0
# Connors, Mr. Patrick                      Connors, Mr. Patrick  male  70.5
# Duane, Mr. Frank                              Duane, Mr. Frank  male  65.0
#
#                                 SibSp  Parch      Ticket     Fare Cabin  \
# Name
# Wheadon, Mr. Edward H               0      0  C.A. 24579  10.5000   NaN
# Ostby, Mr. Engelhart Cornelius      0      1      113509  61.9792   B30
# Goldschmidt, Mr. George B           0      0    PC 17754  34.6542    A5
# Connors, Mr. Patrick                0      0      370369   7.7500   NaN
# Duane, Mr. Frank                    0      0      336439   7.7500   NaN
#
#                                Embarked
# Name
# Wheadon, Mr. Edward H                 S
# Ostby, Mr. Engelhart Cornelius        C
# Goldschmidt, Mr. George B             C
# Connors, Mr. Patrick                  Q
# Duane, Mr. Frank                      Q

# %% [markdown]
# # Replacing Values

# %% [markdown]
# We can replace any instance of "female" in the Sex column with "women"

# %%
#Replace "female" to "women"
datafram['Sex'].replace("female","woman").head()
#datafram['Sex'].replace("woman","female").head()
# Out:
# Name
# Braund, Mr. Owen Harris                                  male
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    female
# Heikkinen, Miss. Laina                                 female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           female
# Allen, Mr. William Henry                                 male
# Name: Sex, dtype: object

# %% [markdown]
# We can also replace multiple values at the same time.

# %%
#replace "female" and "male" with "Women" and "Man"
datafram['Sex'].replace(["female","male"],["Women","Man"]).head()
# Out:
# Name
# Braund, Mr. Owen Harris                                  Man
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    Women
# Heikkinen, Miss. Laina                                 Women
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           Women
# Allen, Mr. William Henry                                 Man
# Name: Sex, dtype: object

# %% [markdown]
# We can also replace the whole data frame instead of a single column

# %%
#replace the whole '1' with "one"
datafram.replace(1,"one").head()
#datafram.replace("one",1).head()
# Out:
#                                                    PassengerId Survived  \
# Name
# Braund, Mr. Owen Harris                                    one        0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...           2      one
# Heikkinen, Miss. Laina                                       3      one
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                 4      one
# Allen, Mr. William Henry                                     5        0
#
#                                                    Pclass  \
# Name
# Braund, Mr. Owen Harris                                 3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...    one
# Heikkinen, Miss. Laina                                  3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)          one
# Allen, Mr. William Henry                                3
#
#                                                                                                  Name  \
# Name
# Braund, Mr. Owen Harris                                                       Braund, Mr. Owen Harris
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  Cumings, Mrs. John Bradley (Florence Briggs Th...
# Heikkinen, Miss. Laina                                                         Heikkinen, Miss. Laina
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Allen, Mr. William Henry                                                     Allen, Mr. William Henry
#
#                                                        Sex Age SibSp Parch  \
# Name
# Braund, Mr. Owen Harris                               male  22   one     0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  female  38   one     0
# Heikkinen, Miss. Laina                              female  26     0     0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        female  35   one     0
# Allen, Mr. William Henry                              male  35     0     0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803  53.1000
# Allen, Mr. William Henry                                      373450   8.0500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        C123        S
# Allen, Mr. William Henry                             NaN        S

# %% [markdown]
# replace also accepts regular expressions

# %%
#replace 'male' with "mele" using regular expression
datafram.replace(r"male","mele",regex=True).head()
#datafram.replace(r"mele","male",regex=True).head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass  \
# Name
# Braund, Mr. Owen Harris                                  3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
# Heikkinen, Miss. Laina                                   3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1
# Allen, Mr. William Henry                                 3
#
#                                                                                                  Name  \
# Name
# Braund, Mr. Owen Harris                                                       Braund, Mr. Owen Harris
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  Cumings, Mrs. John Bradley (Florence Briggs Th...
# Heikkinen, Miss. Laina                                                         Heikkinen, Miss. Laina
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Allen, Mr. William Henry                                                     Allen, Mr. William Henry
#
#                                                        Sex   Age  SibSp  \
# Name
# Braund, Mr. Owen Harris                               mele  22.0      1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  femele  38.0      1
# Heikkinen, Miss. Laina                              femele  26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        femele  35.0      1
# Allen, Mr. William Henry                              mele  35.0      0
#
#                                                     Parch            Ticket  \
# Name
# Braund, Mr. Owen Harris                                 0         A/5 21171
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      0          PC 17599
# Heikkinen, Miss. Laina                                  0  STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            0            113803
# Allen, Mr. William Henry                                0            373450
#
#                                                        Fare Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              7.2500   NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85        C
# Heikkinen, Miss. Laina                               7.9250   NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123        S
# Allen, Mr. William Henry                             8.0500   NaN        S

# %% [markdown]
# # Renaming Columns

# %%
# rename 'Pclass' with 'Passenger Class'
datafram.rename(columns={'Pclass':'Passenger Class'}).head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Passenger Class  \
# Name
# Braund, Mr. Owen Harris                                           3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...                1
# Heikkinen, Miss. Laina                                            3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                      1
# Allen, Mr. William Henry                                          3
#
#                                                                                                  Name  \
# Name
# Braund, Mr. Owen Harris                                                       Braund, Mr. Owen Harris
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  Cumings, Mrs. John Bradley (Florence Briggs Th...
# Heikkinen, Miss. Laina                                                         Heikkinen, Miss. Laina
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Allen, Mr. William Henry                                                     Allen, Mr. William Henry
#
#                                                        Sex   Age  SibSp  \
# Name
# Braund, Mr. Owen Harris                               male  22.0      1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  female  38.0      1
# Heikkinen, Miss. Laina                              female  26.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        female  35.0      1
# Allen, Mr. William Henry                              male  35.0      0
#
#                                                     Parch            Ticket  \
# Name
# Braund, Mr. Owen Harris                                 0         A/5 21171
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      0          PC 17599
# Heikkinen, Miss. Laina                                  0  STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            0            113803
# Allen, Mr. William Henry                                0            373450
#
#                                                        Fare Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              7.2500   NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85        C
# Heikkinen, Miss. Laina                               7.9250   NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123        S
# Allen, Mr. William Henry                             8.0500   NaN        S

# %% [markdown]
# If we want to rename all columns at once, this helpful snippet of code creates a dictionary with the old column names as keys and empty string as values:

# %%
import collections 

#create dictionary
column_names = collections.defaultdict(str)
#create keys 
for name in datafram.columns:
    column_names[name]
column_names
# Out:
# defaultdict(str,
#             {'PassengerId': '',
#              'Age': '',
#              'Name': '',
#              'Embarked': '',
#              'Cabin': '',
#              'Fare': '',
#              'Parch': '',
#              'Passenger Class': '',
#              'Ticket': '',
#              'SibSp': '',
#              'Sex': '',
#              'Survived': ''})

# %% [markdown]
# # Finding the Minimum, Maximum, Sum, Average, and Count

# %%
#load library
import pandas as pd
#create url
url='C:/Users/zhengyi/Desktop/Python Machine Learning Cookbook/testData/titanic.csv'
#load data
dataframe = pd.read_csv(url)

#calculate statistics
print('Maximum:',dataframe['Age'].max())
print('Minimum:',dataframe['Age'].min())
print('Mean:   ',dataframe['Age'].mean())
print('Sum:    ',dataframe['Age'].sum())
print('Count:  ',dataframe['Age'].count())
# Out:
# Maximum: 80.0
# Minimum: 0.42
# Mean:    29.69911764705882
# Sum:     21205.17
# Count:   714

# %%
#show count of the whole data frame
dataframe.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %% [markdown]
# # Finding Unique Values

# %%
#load library
import pandas as pd
#create url
url='C:/Users/zhengyi/Desktop/Python Machine Learning Cookbook/testData/titanic.csv'
#load data
dataframe = pd.read_csv(url)

#select unique values
dataframe['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
#display all unique values with the number of times each value appears:
dataframe['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
dataframe['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
#show number of unique values
dataframe['Pclass'].nunique()
# Out:
# 3

# %% [markdown]
# # Handing Missing Values

# %%
#isnull and notnull return booleans indicating whether a value is missing
import pandas as pd 
url='C:/Users/zhengyi/Desktop/Python Machine Learning Cookbook/testData/titanic.csv'
dataframe = pd.read_csv(url)

#select and show missing values 
dataframe[dataframe['Age'].isnull()].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S
# 19      0      0    2649   7.2250   NaN        C
# 26      0      0    2631   7.2250   NaN        C
# 28      0      0  330959   7.8792   NaN        Q

# %% [markdown]
# pandas uses NumPy's NaN(Not a Number) value to denote missing data, but NaN is not fully implemented in pandas. To have full functionality with NaN we need to import the NumPy library first. What's more pandas' read_csv includes a parameter allowing us to specify the values used to indicate missing values:

# %%
#load data and set missing values 
import numpy as np
dataframe = pd.read_csv(url,na_values=[np.nan,'NONE',-999])
dataframe[dataframe['Age'].isnull()].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S
# 19      0      0    2649   7.2250   NaN        C
# 26      0      0    2631   7.2250   NaN        C
# 28      0      0  330959   7.8792   NaN        Q

# %% [markdown]
# # Deleting a Column

# %% [markdown]
# The best way to delete a column is to use 'drop' with the parameter 'axis=1'(1-->column, 0-->row):

# %%
import pandas as pd 
dataframe = pd.read_csv(url)

#delete column 
dataframe.drop('Age',axis=1).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    male      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                             Heikkinen, Miss. Laina  female      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                           Allen, Mr. William Henry    male      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
#delete multiple column at once
dataframe.drop(['SibSp','Parch'],axis=1).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
#delete column does not have name by its column index using 'dataframe.columns[]':
dataframe.drop(dataframe.columns[1],axis=1).head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
dataframe
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# 【Notice】Many pandas methods include an 'inplace' parameter, which when 'true' edits the data frame directly. When 'inplace = True' means change the data frame, modify the original data object, this saves memory, but results in unrecoverable data.If we have enough memory,we recommend treating DataFrames as immutable objects, you will save youself a lot of headaches down the road.

# %% [markdown]
# # Deleting a Row

# %% [markdown]
# Use a boolean condition to create a new DataFrame excluding the rows you want to delete

# %%
#load library
import pandas as pd 
dataframe = pd.read_csv(url)

#delete 'male' rows 
dataFrame_deleteMale = dataframe[dataframe['Sex']!='male']
dataFrame_deleteMale.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# We can also use the 'drop' method(for example dataframe.drop([0,1],axis=0) to drop the first two rows), a more practical way is simply to use a boolean condition because we can use the power of condition to delete either a single row or many rows at once

# %%
#delete row name = 'Heikkinen, Miss. Laina'
dataFrame_deleteHeikkinen = dataframe[dataframe['Name']!='Heikkinen, Miss. Laina']
dataFrame_deleteHeikkinen.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C
# 3      0     113803  53.1000  C123        S
# 4      0     373450   8.0500   NaN        S
# 5      0     330877   8.4583   NaN        Q

# %%
#delete row by row index
dataframe_deleteByIndex = dataframe[dataframe.index!=0]
dataframe_deleteByIndex.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q

# %% [markdown]
# # Dropping Duplicate Rows

# %%
#Use 'drop_duplicates' to drop the duplicates rows
import pandas as pd 
dataframe = pd.read_csv(url)

dataframe_dropDuplicates = dataframe.drop_duplicates()
dataframe_dropDuplicates.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#show numbers of rows
print("Number of Rows in the original DataFrame:",len(dataframe))
print("Number of Rows after use drop_duplicates:",len(dataframe_dropDuplicates))
# Out:
# Number of Rows in the original DataFrame: 891
# Number of Rows after use drop_duplicates: 891

# %% [markdown]
# The solution didn't drop any rows because of in our DataFrame the data frame is actually unique. However we often want to consider only a subset of columns to check for duplicate row

# %%
dataframe.drop_duplicates(subset = ['Sex'])
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
dataframe.drop_duplicates(subset = ['Sex'],keep = 'last')
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
dataframe.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %% [markdown]
# # Grouping Rows by Values

# %%
#'groupby' is one of the most powerful feature 
import pandas as pd 
dataframe = pd.read_csv(url)

dataframe_Group = dataframe.groupby('Sex').mean()
dataframe_Group.head()
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %% [markdown]
# Users new to use 'groupby' often write a line like this and confused by what is return:

# %%
dataframe.groupby('Sex')

# %% [markdown]
# 'groupby' needs to be paired with some operation we want to apply to each  group, such as calculating an aggregate stastics(mean,min,max,sum,count...)

# %%
dataframe_Group = dataframe.groupby('Survived')['PassengerId'].count()
dataframe_Group
# Out:
# Survived
# 0    549
# 1    342
# Name: PassengerId, dtype: int64

# %%
dataframe_Group = dataframe.groupby('Survived')['Name'].count()
dataframe_Group
# Out:
# Survived
# 0    549
# 1    342
# Name: Name, dtype: int64

# %% [markdown]
# Notice 'Name' and 'Survived' added after the 'groupby'? 'count()' is only meaningful to certain types of data, we can count the survived passengers by their name or PassengerID. Look at the example as follows you may get the idea:

# %%
dataframe_Group = dataframe.groupby('Sex').mean()
dataframe_Group.head()
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
dataframe_Group = dataframe.groupby('Sex')['Survived'].mean()
dataframe_Group.head()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
dataframe_Group = dataframe.groupby('Survived').count()
dataframe_Group
# Out:
#           PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Survived
# 0                 549     549   549  549  424    549    549     549   549
# 1                 342     342   342  342  290    342    342     342   342
#
#           Cabin  Embarked
# Survived
# 0            68       549
# 1           136       340

# %%
dataframe_Group = dataframe.groupby('Survived')['Name'].count()
dataframe_Group
# Out:
# Survived
# 0    549
# 1    342
# Name: Name, dtype: int64

# %% [markdown]
# The parameter what we put in '['parameter(Name,Age)']' in order to make the data more meaningful.

# %% [markdown]
# We also can group by a first column and group that grouping by a second column

# %%
dataframe.groupby(['Sex','Survived'])['Age'].mean()
# Out:
# Sex     Survived
# female  0           25.046875
#         1           28.847716
# male    0           31.618056
#         1           27.276022
# Name: Age, dtype: float64

# %% [markdown]
# We can do some interesting things: Calculate survival rates for different Pclasse

# %%
dataframe.groupby(['Pclass'])['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# Calculate survival rates for men and women of different Pclasse in their class

# %%
dataframe.groupby(['Sex','Pclass'])['Survived'].mean().unstack().plot(kind='bar', figsize=(10, 6))
print(dataframe.groupby(['Sex','Pclass'])['Survived'].mean())
# Out:
# Sex     Pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: Survived, dtype: float64

# %%
dataframe['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
dataframe.groupby(['Sex','Pclass'])['Survived'].value_counts().unstack().plot(kind='bar', figsize=(10, 6))
print(dataframe.groupby(['Sex','Pclass'])['Survived'].value_counts())
# Out:
# Sex     Pclass  Survived
# female  1       1            91
#                 0             3
#         2       1            70
#                 0             6
#         3       0            72
#                 1            72
# male    1       0            77
#                 1            45
#         2       0            91
#                 1            17
#         3       0           300
#                 1            47
# Name: Survived, dtype: int64

# %% [markdown]
# # Grouping Rows by Time

# %% [markdown]
# Group individual rows by time periods

# %%
#load library 
import pandas as pd 
import numpy as np

#create data range
time_index = pd.date_range('06/06/2020',periods=100000,freq='30s')

#create data frame
dataframe = pd.DataFrame(index=time_index)

#create column of random values
dataframe['Sale_Amount'] = np.random.randint(1,10,100000)

#group rows by week, calculate sum per week
dataframe.resample('w').sum()
# Out:
#             Sale_Amount
# 2020-06-07        28813
# 2020-06-14       100205
# 2020-06-21       100673
# 2020-06-28       100610
# 2020-07-05       101039
# 2020-07-12        67765
